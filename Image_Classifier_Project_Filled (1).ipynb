# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import numpy
from collections import OrderedDict
import torch
import os
import time
from google.colab import files
import random
import torchvision
from torch import nn, tensor, optim
from torchvision import datasets, transforms, models
import torch.nn.functional as F
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
normalization = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # creating a variable to hold transforms normalize
# tranining data transforms - has random rotation and flipping to better train our model
training_transforms = transforms.Compose([transforms.RandomRotation(30),
                                        transforms.RandomResizedCrop(224),
                                        transforms.RandomHorizontalFlip(),
                                        transforms.ToTensor(),
                                        normalization])

# validation data transforms - no need for rotation and flippimg
validation_transforms = transforms.Compose([transforms.Resize(256),
                                           transforms.CenterCrop(224),
                                           transforms.ToTensor(),
                                           normalization])

# testing data transforms - no need for rotation and flippimg
testing_transforms = transforms.Compose([transforms.Resize(256),
                                           transforms.CenterCrop(224),
                                           transforms.ToTensor(),
                                           normalization])


# TODO: Load the datasets with ImageFolder
training_datasets = datasets.ImageFolder(train_dir, transform=training_transforms)
print(training_datasets)
validation_datasets = datasets.ImageFolder(valid_dir, transform=validation_transforms)
testing_datasets = datasets.ImageFolder(test_dir, transform=testing_transforms)
# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(training_datasets, batch_size=64, shuffle=True)
print(train_loader)
valid_loader = torch.utils.data.DataLoader(validation_datasets, batch_size=64)
test_loader = torch.utils.data.DataLoader(testing_datasets, batch_size=64)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6552
#     Root location: /content/drive/MyDrive/Colab Notebooks/flowers/train
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-30.0, 30.0], interpolation=nearest, expand=False, fill=0)
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=warn)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# <torch.utils.data.dataloader.DataLoader object at 0x7f1db0af4310>

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('/content/drive/MyDrive/Colab Notebooks/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
model = models.vgg19(pretrained = True) # using pretrained network
for param in model.parameters():
    param.requires_grad = False # freezing our parameters to not collect gradient over time

classifier = nn.Sequential(nn.Linear(25088, 1024), # first input layer
                           nn.Dropout(p=0.5), # defining dropout to help reach error gradient bottom quickly
                           nn.ReLU(),
                           nn.Linear(1024, 102),
                           nn.LogSoftmax(dim=1)
                          )
model.classifier = classifier
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr = 0.001)

# %%
# actually training data
epochs = 8
cuda = torch.cuda.is_available()
if cuda:
    model.cuda()
else:
    model.cpu()
start = time.time()
print("Training started at : {}".format(start))
for e in range(epochs):
    print("Running Epoch {} out of {}".format(e+1, epochs))
    model.train() # telling the model we are training
    training_loss = 0
    training_accuracy = 0
    for i, (images, labels) in enumerate(train_loader): # getting a batch of our training data at a time
        print("Running Batch {} from training data".format(i+1))
        if cuda: # moving traingin data to cuda/GPU if GPU available
            images = images.to('cuda')
            labels = labels.to('cuda')

        #cleaning all previous gradient
        optimizer.zero_grad()
        # forward pass - should go through our sequential model's 3 layers
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step() # taking a step "down" the error gradient
        current_loss = loss.item()
        training_loss += current_loss
        probabilities = torch.exp(outputs).data # raising e to the outputs to get our actual output data
        _, predictions = torch.max(outputs.data, 1)
        equality = predictions.eq(labels.data.view_as(predictions))
        accuracy = torch.mean(equality.type(torch.FloatTensor))
        training_accuracy += accuracy
        print("Batch no: {},  Loss for Batch: {}, Accuracy for Batch: {}".format(i+1, current_loss, accuracy))

    print('Epoch: {}, Overall Training Loss: {}, Overall Training Accuracy: {}'.format(e+1, training_loss/len(train_loader), training_accuracy/len(train_loader)))

end_time = time.time()
print("Training finished at: {}".format(end_time))
print("Total time to run through {} epochs: {}".format(epochs, end_time-start))
# Out:
# Training started at : 1688850381.640839
# Running Epoch 1 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 3.2141666412353516, Accuracy for Batch: 0.25
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 3.4293901920318604, Accuracy for Batch: 0.234375
# Running Batch 3 from training data
# Batch no: 3,  Loss for Batch: 3.7073285579681396, Accuracy for Batch: 0.140625
# Running Batch 4 from training data
# Batch no: 4,  Loss for Batch: 3.17997407913208, Accuracy for Batch: 0.21875
# Running Batch 5 from training data
# Batch no: 5,  Loss for Batch: 2.918959856033325, Accuracy for Batch: 0.21875
# Running Batch 6 from training data
# Batch no: 6,  Loss for Batch: 3.1472344398498535, Accuracy for Batch: 0.28125
# Running Batch 7 from training data
# Batch no: 7,  Loss for Batch: 2.8924601078033447, Accuracy for Batch: 0.265625
# Running Batch 8 from training data
# Batch no: 8,  Loss for Batch: 2.727849245071411, Accuracy for Batch: 0.359375
# Running Batch 9 from training data
# Batch no: 9,  Loss for Batch: 3.400768518447876, Accuracy for Batch: 0.25
# Running Batch 10 from training data
# Batch no: 10,  Loss for Batch: 3.301743745803833, Accuracy for Batch: 0.25
# Running Batch 11 from training data
# Batch no: 11,  Loss for Batch: 3.0972328186035156, Accuracy for Batch: 0.234375
# Running Batch 12 from training data
# Batch no: 12,  Loss for Batch: 3.1108641624450684, Accuracy for Batch: 0.25
# Running Batch 13 from training data
# Batch no: 13,  Loss for Batch: 3.1596012115478516, Accuracy for Batch: 0.21875
# Running Batch 14 from training data
# Batch no: 14,  Loss for Batch: 3.2408816814422607, Accuracy for Batch: 0.265625
# Running Batch 15 from training data
# Batch no: 15,  Loss for Batch: 3.236588716506958, Accuracy for Batch: 0.1875
# Running Batch 16 from training data
# Batch no: 16,  Loss for Batch: 3.1707603931427, Accuracy for Batch: 0.171875
# Running Batch 17 from training data
# Batch no: 17,  Loss for Batch: 2.9373176097869873, Accuracy for Batch: 0.25
# Running Batch 18 from training data
# Batch no: 18,  Loss for Batch: 3.0742857456207275, Accuracy for Batch: 0.234375
# Running Batch 19 from training data
# Batch no: 19,  Loss for Batch: 2.9109890460968018, Accuracy for Batch: 0.3125
# Running Batch 20 from training data
# Batch no: 20,  Loss for Batch: 3.181204080581665, Accuracy for Batch: 0.1875
# Running Batch 21 from training data
# Batch no: 21,  Loss for Batch: 3.227897882461548, Accuracy for Batch: 0.15625
# Running Batch 22 from training data
# Batch no: 22,  Loss for Batch: 3.1674294471740723, Accuracy for Batch: 0.234375
# Running Batch 23 from training data
# Batch no: 23,  Loss for Batch: 3.150580883026123, Accuracy for Batch: 0.234375
# Running Batch 24 from training data
# Batch no: 24,  Loss for Batch: 2.7717854976654053, Accuracy for Batch: 0.375
# Running Batch 25 from training data
# Batch no: 25,  Loss for Batch: 3.0723674297332764, Accuracy for Batch: 0.265625
# Running Batch 26 from training data
# Batch no: 26,  Loss for Batch: 3.100931167602539, Accuracy for Batch: 0.265625
# Running Batch 27 from training data
# Batch no: 27,  Loss for Batch: 3.238468885421753, Accuracy for Batch: 0.25
# Running Batch 28 from training data
# Batch no: 28,  Loss for Batch: 2.6776962280273438, Accuracy for Batch: 0.296875
# Running Batch 29 from training data
# Batch no: 29,  Loss for Batch: 3.1292331218719482, Accuracy for Batch: 0.25
# Running Batch 30 from training data
# Batch no: 30,  Loss for Batch: 3.021461009979248, Accuracy for Batch: 0.28125
# Running Batch 31 from training data
# Batch no: 31,  Loss for Batch: 2.5235705375671387, Accuracy for Batch: 0.421875
# Running Batch 32 from training data
# Batch no: 32,  Loss for Batch: 3.011603832244873, Accuracy for Batch: 0.265625
# Running Batch 33 from training data
# Batch no: 33,  Loss for Batch: 2.853548288345337, Accuracy for Batch: 0.265625
# Running Batch 34 from training data
# Batch no: 34,  Loss for Batch: 2.9783382415771484, Accuracy for Batch: 0.203125
# Running Batch 35 from training data
# Batch no: 35,  Loss for Batch: 2.8952817916870117, Accuracy for Batch: 0.296875
# Running Batch 36 from training data
# Batch no: 36,  Loss for Batch: 3.0621824264526367, Accuracy for Batch: 0.234375
# Running Batch 37 from training data
# Batch no: 37,  Loss for Batch: 2.780184745788574, Accuracy for Batch: 0.296875
# Running Batch 38 from training data
# Batch no: 38,  Loss for Batch: 2.892385959625244, Accuracy for Batch: 0.34375
# Running Batch 39 from training data
# Batch no: 39,  Loss for Batch: 2.9285826683044434, Accuracy for Batch: 0.328125
# Running Batch 40 from training data
# Batch no: 40,  Loss for Batch: 2.980130195617676, Accuracy for Batch: 0.296875
# Running Batch 41 from training data
# Batch no: 41,  Loss for Batch: 2.8204681873321533, Accuracy for Batch: 0.28125
# Running Batch 42 from training data
# Batch no: 42,  Loss for Batch: 2.0687599182128906, Accuracy for Batch: 0.5
# Running Batch 43 from training data
# Batch no: 43,  Loss for Batch: 2.8057198524475098, Accuracy for Batch: 0.25
# Running Batch 44 from training data
# Batch no: 44,  Loss for Batch: 2.8282949924468994, Accuracy for Batch: 0.34375
# Running Batch 45 from training data
# Batch no: 45,  Loss for Batch: 2.8772053718566895, Accuracy for Batch: 0.3125
# Running Batch 46 from training data
# Batch no: 46,  Loss for Batch: 2.8286895751953125, Accuracy for Batch: 0.28125
# Running Batch 47 from training data
# Batch no: 47,  Loss for Batch: 2.704169750213623, Accuracy for Batch: 0.34375
# Running Batch 48 from training data
# Batch no: 48,  Loss for Batch: 2.9944517612457275, Accuracy for Batch: 0.28125
# Running Batch 49 from training data
# Batch no: 49,  Loss for Batch: 3.1805169582366943, Accuracy for Batch: 0.234375
# Running Batch 50 from training data
# Batch no: 50,  Loss for Batch: 2.793187379837036, Accuracy for Batch: 0.28125
# Running Batch 51 from training data
# Batch no: 51,  Loss for Batch: 2.854633331298828, Accuracy for Batch: 0.296875
# Running Batch 52 from training data
# Batch no: 52,  Loss for Batch: 3.28432297706604, Accuracy for Batch: 0.1875
# Running Batch 53 from training data
# Batch no: 53,  Loss for Batch: 2.379779577255249, Accuracy for Batch: 0.359375
# Running Batch 54 from training data
# Batch no: 54,  Loss for Batch: 3.088057279586792, Accuracy for Batch: 0.234375
# Running Batch 55 from training data
# Batch no: 55,  Loss for Batch: 2.7067863941192627, Accuracy for Batch: 0.3125
# Running Batch 56 from training data
# Batch no: 56,  Loss for Batch: 2.8822710514068604, Accuracy for Batch: 0.328125
# Running Batch 57 from training data
# Batch no: 57,  Loss for Batch: 2.7056336402893066, Accuracy for Batch: 0.28125
# Running Batch 58 from training data
# Batch no: 58,  Loss for Batch: 2.661445140838623, Accuracy for Batch: 0.359375
# Running Batch 59 from training data
# Batch no: 59,  Loss for Batch: 2.775979518890381, Accuracy for Batch: 0.28125
# Running Batch 60 from training data
# Batch no: 60,  Loss for Batch: 2.607992172241211, Accuracy for Batch: 0.328125
# Running Batch 61 from training data
# Batch no: 61,  Loss for Batch: 2.64932918548584, Accuracy for Batch: 0.296875
# Running Batch 62 from training data
# Batch no: 62,  Loss for Batch: 2.9101319313049316, Accuracy for Batch: 0.296875
# Running Batch 63 from training data
# Batch no: 63,  Loss for Batch: 2.2780885696411133, Accuracy for Batch: 0.421875
# Running Batch 64 from training data
# Batch no: 64,  Loss for Batch: 2.575399875640869, Accuracy for Batch: 0.34375
# Running Batch 65 from training data
# Batch no: 65,  Loss for Batch: 2.726215362548828, Accuracy for Batch: 0.28125
# Running Batch 66 from training data
# Batch no: 66,  Loss for Batch: 2.802328586578369, Accuracy for Batch: 0.265625
# Running Batch 67 from training data
# Batch no: 67,  Loss for Batch: 2.671700954437256, Accuracy for Batch: 0.234375
# Running Batch 68 from training data
# Batch no: 68,  Loss for Batch: 2.817829132080078, Accuracy for Batch: 0.34375
# Running Batch 69 from training data
# Batch no: 69,  Loss for Batch: 2.127197027206421, Accuracy for Batch: 0.390625
# Running Batch 70 from training data
# Batch no: 70,  Loss for Batch: 2.4706950187683105, Accuracy for Batch: 0.390625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 2.6481001377105713, Accuracy for Batch: 0.34375
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 2.3850855827331543, Accuracy for Batch: 0.453125
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.8501546382904053, Accuracy for Batch: 0.203125
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 2.6760993003845215, Accuracy for Batch: 0.296875
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 2.630540609359741, Accuracy for Batch: 0.328125
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 2.5568063259124756, Accuracy for Batch: 0.375
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 2.5510671138763428, Accuracy for Batch: 0.359375
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 2.574103832244873, Accuracy for Batch: 0.34375
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 2.5893025398254395, Accuracy for Batch: 0.328125
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 2.343038320541382, Accuracy for Batch: 0.40625
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 2.6050820350646973, Accuracy for Batch: 0.34375
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 3.1124680042266846, Accuracy for Batch: 0.21875
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 2.7980692386627197, Accuracy for Batch: 0.234375
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 2.538332939147949, Accuracy for Batch: 0.4375
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 2.6220061779022217, Accuracy for Batch: 0.375
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 2.532910108566284, Accuracy for Batch: 0.296875
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 2.838701009750366, Accuracy for Batch: 0.28125
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 2.9325814247131348, Accuracy for Batch: 0.25
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 2.720583438873291, Accuracy for Batch: 0.421875
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 2.8376693725585938, Accuracy for Batch: 0.296875
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 2.656533718109131, Accuracy for Batch: 0.3125
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 2.8964555263519287, Accuracy for Batch: 0.25
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 2.262881278991699, Accuracy for Batch: 0.34375
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 2.7907814979553223, Accuracy for Batch: 0.390625
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 2.5627520084381104, Accuracy for Batch: 0.328125
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 2.7397146224975586, Accuracy for Batch: 0.234375
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 2.65669322013855, Accuracy for Batch: 0.3125
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 2.6329030990600586, Accuracy for Batch: 0.328125
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.617497682571411, Accuracy for Batch: 0.296875
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 2.4604291915893555, Accuracy for Batch: 0.40625
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 2.680238723754883, Accuracy for Batch: 0.359375
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 2.649310350418091, Accuracy for Batch: 0.3125
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 2.049760580062866, Accuracy for Batch: 0.4583333432674408
# Epoch: 1, Overall Training Loss: 2.828924225372018, Overall Training Accuracy: 0.29722896218299866
# Running Epoch 2 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 2.8588626384735107, Accuracy for Batch: 0.25
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 2.051283597946167, Accuracy for Batch: 0.4375
# Running Batch 3 from training data
# Batch no: 3,  Loss for Batch: 2.3238370418548584, Accuracy for Batch: 0.359375
# Running Batch 4 from training data
# Batch no: 4,  Loss for Batch: 2.802276849746704, Accuracy for Batch: 0.28125
# Running Batch 5 from training data
# Batch no: 5,  Loss for Batch: 2.466294288635254, Accuracy for Batch: 0.34375
# Running Batch 6 from training data
# Batch no: 6,  Loss for Batch: 2.647754192352295, Accuracy for Batch: 0.265625
# Running Batch 7 from training data
# Batch no: 7,  Loss for Batch: 2.8155038356781006, Accuracy for Batch: 0.25
# Running Batch 8 from training data
# Batch no: 8,  Loss for Batch: 2.2954671382904053, Accuracy for Batch: 0.453125
# Running Batch 9 from training data
# Batch no: 9,  Loss for Batch: 3.050483226776123, Accuracy for Batch: 0.203125
# Running Batch 10 from training data
# Batch no: 10,  Loss for Batch: 2.6570241451263428, Accuracy for Batch: 0.34375
# Running Batch 11 from training data
# Batch no: 11,  Loss for Batch: 2.6418416500091553, Accuracy for Batch: 0.359375
# Running Batch 12 from training data
# Batch no: 12,  Loss for Batch: 2.693424940109253, Accuracy for Batch: 0.28125
# Running Batch 13 from training data
# Batch no: 13,  Loss for Batch: 2.6547694206237793, Accuracy for Batch: 0.265625
# Running Batch 14 from training data
# Batch no: 14,  Loss for Batch: 2.35402774810791, Accuracy for Batch: 0.421875
# Running Batch 15 from training data
# Batch no: 15,  Loss for Batch: 2.2270491123199463, Accuracy for Batch: 0.4375
# Running Batch 16 from training data
# Batch no: 16,  Loss for Batch: 2.4261696338653564, Accuracy for Batch: 0.421875
# Running Batch 17 from training data
# Batch no: 17,  Loss for Batch: 2.50228214263916, Accuracy for Batch: 0.375
# Running Batch 18 from training data
# Batch no: 18,  Loss for Batch: 2.520798921585083, Accuracy for Batch: 0.296875
# Running Batch 19 from training data
# Batch no: 19,  Loss for Batch: 2.6514718532562256, Accuracy for Batch: 0.3125
# Running Batch 20 from training data
# Batch no: 20,  Loss for Batch: 2.2995455265045166, Accuracy for Batch: 0.453125
# Running Batch 21 from training data
# Batch no: 21,  Loss for Batch: 2.6417808532714844, Accuracy for Batch: 0.3125
# Running Batch 22 from training data
# Batch no: 22,  Loss for Batch: 2.538004159927368, Accuracy for Batch: 0.328125
# Running Batch 23 from training data
# Batch no: 23,  Loss for Batch: 2.26220703125, Accuracy for Batch: 0.421875
# Running Batch 24 from training data
# Batch no: 24,  Loss for Batch: 2.1719436645507812, Accuracy for Batch: 0.4375
# Running Batch 25 from training data
# Batch no: 25,  Loss for Batch: 2.5258796215057373, Accuracy for Batch: 0.328125
# Running Batch 26 from training data
# Batch no: 26,  Loss for Batch: 2.436357021331787, Accuracy for Batch: 0.484375
# Running Batch 27 from training data
# Batch no: 27,  Loss for Batch: 2.3439974784851074, Accuracy for Batch: 0.390625
# Running Batch 28 from training data
# Batch no: 28,  Loss for Batch: 2.2981386184692383, Accuracy for Batch: 0.375
# Running Batch 29 from training data
# Batch no: 29,  Loss for Batch: 2.550477981567383, Accuracy for Batch: 0.3125
# Running Batch 30 from training data
# Batch no: 30,  Loss for Batch: 2.041900157928467, Accuracy for Batch: 0.5
# Running Batch 31 from training data
# Batch no: 31,  Loss for Batch: 2.4133808612823486, Accuracy for Batch: 0.359375
# Running Batch 32 from training data
# Batch no: 32,  Loss for Batch: 2.2281739711761475, Accuracy for Batch: 0.40625
# Running Batch 33 from training data
# Batch no: 33,  Loss for Batch: 2.031165838241577, Accuracy for Batch: 0.5
# Running Batch 34 from training data
# Batch no: 34,  Loss for Batch: 2.5381906032562256, Accuracy for Batch: 0.390625
# Running Batch 35 from training data
# Batch no: 35,  Loss for Batch: 2.492664098739624, Accuracy for Batch: 0.328125
# Running Batch 36 from training data
# Batch no: 36,  Loss for Batch: 2.689168930053711, Accuracy for Batch: 0.34375
# Running Batch 37 from training data
# Batch no: 37,  Loss for Batch: 2.409336805343628, Accuracy for Batch: 0.296875
# Running Batch 38 from training data
# Batch no: 38,  Loss for Batch: 2.472019910812378, Accuracy for Batch: 0.296875
# Running Batch 39 from training data
# Batch no: 39,  Loss for Batch: 2.889413356781006, Accuracy for Batch: 0.28125
# Running Batch 40 from training data
# Batch no: 40,  Loss for Batch: 2.2443466186523438, Accuracy for Batch: 0.359375
# Running Batch 41 from training data
# Batch no: 41,  Loss for Batch: 3.007551431655884, Accuracy for Batch: 0.21875
# Running Batch 42 from training data
# Batch no: 42,  Loss for Batch: 2.3233940601348877, Accuracy for Batch: 0.4375
# Running Batch 43 from training data
# Batch no: 43,  Loss for Batch: 2.711010456085205, Accuracy for Batch: 0.328125
# Running Batch 44 from training data
# Batch no: 44,  Loss for Batch: 2.312870979309082, Accuracy for Batch: 0.390625
# Running Batch 45 from training data
# Batch no: 45,  Loss for Batch: 2.3068172931671143, Accuracy for Batch: 0.390625
# Running Batch 46 from training data
# Batch no: 46,  Loss for Batch: 2.1757724285125732, Accuracy for Batch: 0.359375
# Running Batch 47 from training data
# Batch no: 47,  Loss for Batch: 2.145848035812378, Accuracy for Batch: 0.375
# Running Batch 48 from training data
# Batch no: 48,  Loss for Batch: 2.089080572128296, Accuracy for Batch: 0.4375
# Running Batch 49 from training data
# Batch no: 49,  Loss for Batch: 2.3310158252716064, Accuracy for Batch: 0.359375
# Running Batch 50 from training data
# Batch no: 50,  Loss for Batch: 2.2281911373138428, Accuracy for Batch: 0.453125
# Running Batch 51 from training data
# Batch no: 51,  Loss for Batch: 2.281998634338379, Accuracy for Batch: 0.359375
# Running Batch 52 from training data
# Batch no: 52,  Loss for Batch: 2.066807985305786, Accuracy for Batch: 0.40625
# Running Batch 53 from training data
# Batch no: 53,  Loss for Batch: 2.394745111465454, Accuracy for Batch: 0.375
# Running Batch 54 from training data
# Batch no: 54,  Loss for Batch: 2.3937249183654785, Accuracy for Batch: 0.34375
# Running Batch 55 from training data
# Batch no: 55,  Loss for Batch: 2.6111459732055664, Accuracy for Batch: 0.359375
# Running Batch 56 from training data
# Batch no: 56,  Loss for Batch: 2.2765583992004395, Accuracy for Batch: 0.296875
# Running Batch 57 from training data
# Batch no: 57,  Loss for Batch: 2.42952561378479, Accuracy for Batch: 0.375
# Running Batch 58 from training data
# Batch no: 58,  Loss for Batch: 2.329749822616577, Accuracy for Batch: 0.359375
# Running Batch 59 from training data
# Batch no: 59,  Loss for Batch: 2.8645076751708984, Accuracy for Batch: 0.3125
# Running Batch 60 from training data
# Batch no: 60,  Loss for Batch: 2.4652068614959717, Accuracy for Batch: 0.328125
# Running Batch 61 from training data
# Batch no: 61,  Loss for Batch: 2.0084474086761475, Accuracy for Batch: 0.40625
# Running Batch 62 from training data
# Batch no: 62,  Loss for Batch: 2.7236716747283936, Accuracy for Batch: 0.375
# Running Batch 63 from training data
# Batch no: 63,  Loss for Batch: 2.3272299766540527, Accuracy for Batch: 0.375
# Running Batch 64 from training data
# Batch no: 64,  Loss for Batch: 2.4574220180511475, Accuracy for Batch: 0.40625
# Running Batch 65 from training data
# Batch no: 65,  Loss for Batch: 2.6881954669952393, Accuracy for Batch: 0.390625
# Running Batch 66 from training data
# Batch no: 66,  Loss for Batch: 2.205625057220459, Accuracy for Batch: 0.40625
# Running Batch 67 from training data
# Batch no: 67,  Loss for Batch: 2.6031064987182617, Accuracy for Batch: 0.359375
# Running Batch 68 from training data
# Batch no: 68,  Loss for Batch: 2.5479061603546143, Accuracy for Batch: 0.40625
# Running Batch 69 from training data
# Batch no: 69,  Loss for Batch: 2.425995349884033, Accuracy for Batch: 0.40625
# Running Batch 70 from training data
# Batch no: 70,  Loss for Batch: 1.8079712390899658, Accuracy for Batch: 0.515625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 2.2665019035339355, Accuracy for Batch: 0.421875
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 2.580885887145996, Accuracy for Batch: 0.34375
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.2970316410064697, Accuracy for Batch: 0.484375
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 2.2095229625701904, Accuracy for Batch: 0.390625
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 2.4056520462036133, Accuracy for Batch: 0.34375
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 2.126394510269165, Accuracy for Batch: 0.46875
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 2.4676108360290527, Accuracy for Batch: 0.40625
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 2.127920389175415, Accuracy for Batch: 0.4375
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 2.463622570037842, Accuracy for Batch: 0.359375
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 2.239689350128174, Accuracy for Batch: 0.328125
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 2.2478108406066895, Accuracy for Batch: 0.4375
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 2.3249759674072266, Accuracy for Batch: 0.4375
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 2.4952032566070557, Accuracy for Batch: 0.46875
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 2.6926517486572266, Accuracy for Batch: 0.359375
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 2.2033960819244385, Accuracy for Batch: 0.359375
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 2.519744396209717, Accuracy for Batch: 0.28125
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 2.1226537227630615, Accuracy for Batch: 0.421875
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 2.3159122467041016, Accuracy for Batch: 0.453125
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 2.137139320373535, Accuracy for Batch: 0.40625
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 2.2562570571899414, Accuracy for Batch: 0.4375
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 1.9510862827301025, Accuracy for Batch: 0.515625
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 1.9117522239685059, Accuracy for Batch: 0.5
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 2.1810672283172607, Accuracy for Batch: 0.40625
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 2.8135032653808594, Accuracy for Batch: 0.328125
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 2.4293935298919678, Accuracy for Batch: 0.375
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 2.3579370975494385, Accuracy for Batch: 0.375
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 2.1222307682037354, Accuracy for Batch: 0.4375
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 2.4774363040924072, Accuracy for Batch: 0.3125
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.061429500579834, Accuracy for Batch: 0.5
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 2.269850254058838, Accuracy for Batch: 0.328125
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 2.476778984069824, Accuracy for Batch: 0.375
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 2.4548542499542236, Accuracy for Batch: 0.28125
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 2.6869335174560547, Accuracy for Batch: 0.25
# Epoch: 2, Overall Training Loss: 2.401889703806164, Overall Training Accuracy: 0.37484830617904663
# Running Epoch 3 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 2.72163724899292, Accuracy for Batch: 0.328125
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 2.0106430053710938, Accuracy for Batch: 0.4375
# Running Batch 3 from training data
# Batch no: 3,  Loss for Batch: 2.181842803955078, Accuracy for Batch: 0.4375
# Running Batch 4 from training data
# Batch no: 4,  Loss for Batch: 2.1703481674194336, Accuracy for Batch: 0.421875
# Running Batch 5 from training data
# Batch no: 5,  Loss for Batch: 2.305966854095459, Accuracy for Batch: 0.34375
# Running Batch 6 from training data
# Batch no: 6,  Loss for Batch: 2.1023361682891846, Accuracy for Batch: 0.375
# Running Batch 7 from training data
# Batch no: 7,  Loss for Batch: 2.2107560634613037, Accuracy for Batch: 0.359375
# Running Batch 8 from training data
# Batch no: 8,  Loss for Batch: 2.506977081298828, Accuracy for Batch: 0.359375
# Running Batch 9 from training data
# Batch no: 9,  Loss for Batch: 2.460371732711792, Accuracy for Batch: 0.34375
# Running Batch 10 from training data
# Batch no: 10,  Loss for Batch: 1.8013049364089966, Accuracy for Batch: 0.515625
# Running Batch 11 from training data
# Batch no: 11,  Loss for Batch: 2.38847017288208, Accuracy for Batch: 0.359375
# Running Batch 12 from training data
# Batch no: 12,  Loss for Batch: 1.9950124025344849, Accuracy for Batch: 0.5
# Running Batch 13 from training data
# Batch no: 13,  Loss for Batch: 2.446589231491089, Accuracy for Batch: 0.375
# Running Batch 14 from training data
# Batch no: 14,  Loss for Batch: 2.453191041946411, Accuracy for Batch: 0.34375
# Running Batch 15 from training data
# Batch no: 15,  Loss for Batch: 2.2479612827301025, Accuracy for Batch: 0.359375
# Running Batch 16 from training data
# Batch no: 16,  Loss for Batch: 1.7631257772445679, Accuracy for Batch: 0.5
# Running Batch 17 from training data
# Batch no: 17,  Loss for Batch: 2.270134687423706, Accuracy for Batch: 0.4375
# Running Batch 18 from training data
# Batch no: 18,  Loss for Batch: 2.319486141204834, Accuracy for Batch: 0.359375
# Running Batch 19 from training data
# Batch no: 19,  Loss for Batch: 2.1212103366851807, Accuracy for Batch: 0.5
# Running Batch 20 from training data
# Batch no: 20,  Loss for Batch: 2.2477338314056396, Accuracy for Batch: 0.34375
# Running Batch 21 from training data
# Batch no: 21,  Loss for Batch: 2.3637406826019287, Accuracy for Batch: 0.3125
# Running Batch 22 from training data
# Batch no: 22,  Loss for Batch: 2.1822030544281006, Accuracy for Batch: 0.390625
# Running Batch 23 from training data
# Batch no: 23,  Loss for Batch: 2.4349162578582764, Accuracy for Batch: 0.421875
# Running Batch 24 from training data
# Batch no: 24,  Loss for Batch: 2.5641238689422607, Accuracy for Batch: 0.3125
# Running Batch 25 from training data
# Batch no: 25,  Loss for Batch: 2.368098497390747, Accuracy for Batch: 0.34375
# Running Batch 26 from training data
# Batch no: 26,  Loss for Batch: 2.2915170192718506, Accuracy for Batch: 0.453125
# Running Batch 27 from training data
# Batch no: 27,  Loss for Batch: 2.488236904144287, Accuracy for Batch: 0.375
# Running Batch 28 from training data
# Batch no: 28,  Loss for Batch: 1.872282862663269, Accuracy for Batch: 0.5
# Running Batch 29 from training data
# Batch no: 29,  Loss for Batch: 2.2578601837158203, Accuracy for Batch: 0.40625
# Running Batch 30 from training data
# Batch no: 30,  Loss for Batch: 2.2802205085754395, Accuracy for Batch: 0.453125
# Running Batch 31 from training data
# Batch no: 31,  Loss for Batch: 2.424614667892456, Accuracy for Batch: 0.40625
# Running Batch 32 from training data
# Batch no: 32,  Loss for Batch: 1.697824478149414, Accuracy for Batch: 0.484375
# Running Batch 33 from training data
# Batch no: 33,  Loss for Batch: 2.5416922569274902, Accuracy for Batch: 0.328125
# Running Batch 34 from training data
# Batch no: 34,  Loss for Batch: 2.3313486576080322, Accuracy for Batch: 0.390625
# Running Batch 35 from training data
# Batch no: 35,  Loss for Batch: 2.0266215801239014, Accuracy for Batch: 0.46875
# Running Batch 36 from training data
# Batch no: 36,  Loss for Batch: 2.1550099849700928, Accuracy for Batch: 0.390625
# Running Batch 37 from training data
# Batch no: 37,  Loss for Batch: 2.5458085536956787, Accuracy for Batch: 0.328125
# Running Batch 38 from training data
# Batch no: 38,  Loss for Batch: 2.4328715801239014, Accuracy for Batch: 0.390625
# Running Batch 39 from training data
# Batch no: 39,  Loss for Batch: 1.9826455116271973, Accuracy for Batch: 0.4375
# Running Batch 40 from training data
# Batch no: 40,  Loss for Batch: 1.8985249996185303, Accuracy for Batch: 0.40625
# Running Batch 41 from training data
# Batch no: 41,  Loss for Batch: 2.250039577484131, Accuracy for Batch: 0.421875
# Running Batch 42 from training data
# Batch no: 42,  Loss for Batch: 2.250795841217041, Accuracy for Batch: 0.40625
# Running Batch 43 from training data
# Batch no: 43,  Loss for Batch: 2.1001157760620117, Accuracy for Batch: 0.421875
# Running Batch 44 from training data
# Batch no: 44,  Loss for Batch: 2.353485345840454, Accuracy for Batch: 0.375
# Running Batch 45 from training data
# Batch no: 45,  Loss for Batch: 2.0555102825164795, Accuracy for Batch: 0.40625
# Running Batch 46 from training data
# Batch no: 46,  Loss for Batch: 2.012906551361084, Accuracy for Batch: 0.484375
# Running Batch 47 from training data
# Batch no: 47,  Loss for Batch: 2.446739673614502, Accuracy for Batch: 0.4375
# Running Batch 48 from training data
# Batch no: 48,  Loss for Batch: 2.0387585163116455, Accuracy for Batch: 0.4375
# Running Batch 49 from training data
# Batch no: 49,  Loss for Batch: 2.2415482997894287, Accuracy for Batch: 0.453125
# Running Batch 50 from training data
# Batch no: 50,  Loss for Batch: 2.478036642074585, Accuracy for Batch: 0.3125
# Running Batch 51 from training data
# Batch no: 51,  Loss for Batch: 2.3772411346435547, Accuracy for Batch: 0.453125
# Running Batch 52 from training data
# Batch no: 52,  Loss for Batch: 2.2458105087280273, Accuracy for Batch: 0.421875
# Running Batch 53 from training data
# Batch no: 53,  Loss for Batch: 2.094836950302124, Accuracy for Batch: 0.46875
# Running Batch 54 from training data
# Batch no: 54,  Loss for Batch: 2.213350534439087, Accuracy for Batch: 0.453125
# Running Batch 55 from training data
# Batch no: 55,  Loss for Batch: 2.0857019424438477, Accuracy for Batch: 0.421875
# Running Batch 56 from training data
# Batch no: 56,  Loss for Batch: 2.1874868869781494, Accuracy for Batch: 0.390625
# Running Batch 57 from training data
# Batch no: 57,  Loss for Batch: 2.125777006149292, Accuracy for Batch: 0.453125
# Running Batch 58 from training data
# Batch no: 58,  Loss for Batch: 2.2135276794433594, Accuracy for Batch: 0.453125
# Running Batch 59 from training data
# Batch no: 59,  Loss for Batch: 2.161022424697876, Accuracy for Batch: 0.46875
# Running Batch 60 from training data
# Batch no: 60,  Loss for Batch: 1.6939201354980469, Accuracy for Batch: 0.5625
# Running Batch 61 from training data
# Batch no: 61,  Loss for Batch: 2.232530117034912, Accuracy for Batch: 0.5
# Running Batch 62 from training data
# Batch no: 62,  Loss for Batch: 2.296837329864502, Accuracy for Batch: 0.359375
# Running Batch 63 from training data
# Batch no: 63,  Loss for Batch: 2.291922092437744, Accuracy for Batch: 0.3125
# Running Batch 64 from training data
# Batch no: 64,  Loss for Batch: 2.090933084487915, Accuracy for Batch: 0.390625
# Running Batch 65 from training data
# Batch no: 65,  Loss for Batch: 2.2143824100494385, Accuracy for Batch: 0.328125
# Running Batch 66 from training data
# Batch no: 66,  Loss for Batch: 2.09895920753479, Accuracy for Batch: 0.453125
# Running Batch 67 from training data
# Batch no: 67,  Loss for Batch: 1.7885582447052002, Accuracy for Batch: 0.578125
# Running Batch 68 from training data
# Batch no: 68,  Loss for Batch: 2.5208239555358887, Accuracy for Batch: 0.328125
# Running Batch 69 from training data
# Batch no: 69,  Loss for Batch: 1.9218541383743286, Accuracy for Batch: 0.46875
# Running Batch 70 from training data
# Batch no: 70,  Loss for Batch: 2.1774868965148926, Accuracy for Batch: 0.515625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 1.8011908531188965, Accuracy for Batch: 0.5
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 2.010530948638916, Accuracy for Batch: 0.484375
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.2074098587036133, Accuracy for Batch: 0.390625
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 1.8476287126541138, Accuracy for Batch: 0.484375
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 1.993852138519287, Accuracy for Batch: 0.4375
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 2.6600759029388428, Accuracy for Batch: 0.3125
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 2.2655012607574463, Accuracy for Batch: 0.453125
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 2.2764976024627686, Accuracy for Batch: 0.46875
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 2.003533363342285, Accuracy for Batch: 0.515625
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 2.2628772258758545, Accuracy for Batch: 0.359375
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 2.0880870819091797, Accuracy for Batch: 0.53125
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 2.6556923389434814, Accuracy for Batch: 0.359375
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 2.6047627925872803, Accuracy for Batch: 0.328125
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 1.8682754039764404, Accuracy for Batch: 0.5
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 1.880850076675415, Accuracy for Batch: 0.421875
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 2.090496301651001, Accuracy for Batch: 0.46875
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 2.1834232807159424, Accuracy for Batch: 0.375
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 1.7532579898834229, Accuracy for Batch: 0.53125
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 2.132441759109497, Accuracy for Batch: 0.453125
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 2.1815741062164307, Accuracy for Batch: 0.46875
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 2.2863619327545166, Accuracy for Batch: 0.40625
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 1.8218992948532104, Accuracy for Batch: 0.453125
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 2.0031936168670654, Accuracy for Batch: 0.5
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 2.3856914043426514, Accuracy for Batch: 0.34375
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 2.2942140102386475, Accuracy for Batch: 0.375
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 2.0259246826171875, Accuracy for Batch: 0.421875
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 2.554701805114746, Accuracy for Batch: 0.359375
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 1.5039786100387573, Accuracy for Batch: 0.53125
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.2177934646606445, Accuracy for Batch: 0.421875
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 2.4619154930114746, Accuracy for Batch: 0.4375
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 2.1689462661743164, Accuracy for Batch: 0.421875
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 2.1987152099609375, Accuracy for Batch: 0.40625
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 2.2209227085113525, Accuracy for Batch: 0.5416666865348816
# Epoch: 3, Overall Training Loss: 2.194547356911076, Overall Training Accuracy: 0.421369343996048
# Running Epoch 4 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 1.8213396072387695, Accuracy for Batch: 0.5
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 2.0299670696258545, Accuracy for Batch: 0.40625
# Running Batch 3 from training data
# Batch no: 3,  Loss for Batch: 2.5160391330718994, Accuracy for Batch: 0.28125
# Running Batch 4 from training data
# Batch no: 4,  Loss for Batch: 1.9081707000732422, Accuracy for Batch: 0.453125
# Running Batch 5 from training data
# Batch no: 5,  Loss for Batch: 1.941347360610962, Accuracy for Batch: 0.484375
# Running Batch 6 from training data
# Batch no: 6,  Loss for Batch: 2.003811836242676, Accuracy for Batch: 0.53125
# Running Batch 7 from training data
# Batch no: 7,  Loss for Batch: 2.4798920154571533, Accuracy for Batch: 0.375
# Running Batch 8 from training data
# Batch no: 8,  Loss for Batch: 2.238577127456665, Accuracy for Batch: 0.453125
# Running Batch 9 from training data
# Batch no: 9,  Loss for Batch: 1.9184976816177368, Accuracy for Batch: 0.46875
# Running Batch 10 from training data
# Batch no: 10,  Loss for Batch: 1.87462317943573, Accuracy for Batch: 0.53125
# Running Batch 11 from training data
# Batch no: 11,  Loss for Batch: 1.6551213264465332, Accuracy for Batch: 0.515625
# Running Batch 12 from training data
# Batch no: 12,  Loss for Batch: 2.5674030780792236, Accuracy for Batch: 0.4375
# Running Batch 13 from training data
# Batch no: 13,  Loss for Batch: 2.102543830871582, Accuracy for Batch: 0.484375
# Running Batch 14 from training data
# Batch no: 14,  Loss for Batch: 2.6309473514556885, Accuracy for Batch: 0.25
# Running Batch 15 from training data
# Batch no: 15,  Loss for Batch: 2.4155569076538086, Accuracy for Batch: 0.40625
# Running Batch 16 from training data
# Batch no: 16,  Loss for Batch: 2.016146421432495, Accuracy for Batch: 0.4375
# Running Batch 17 from training data
# Batch no: 17,  Loss for Batch: 2.0267553329467773, Accuracy for Batch: 0.4375
# Running Batch 18 from training data
# Batch no: 18,  Loss for Batch: 1.8671666383743286, Accuracy for Batch: 0.515625
# Running Batch 19 from training data
# Batch no: 19,  Loss for Batch: 2.3999485969543457, Accuracy for Batch: 0.453125
# Running Batch 20 from training data
# Batch no: 20,  Loss for Batch: 2.065441608428955, Accuracy for Batch: 0.40625
# Running Batch 21 from training data
# Batch no: 21,  Loss for Batch: 2.2309374809265137, Accuracy for Batch: 0.34375
# Running Batch 22 from training data
# Batch no: 22,  Loss for Batch: 1.8924232721328735, Accuracy for Batch: 0.484375
# Running Batch 23 from training data
# Batch no: 23,  Loss for Batch: 1.979678750038147, Accuracy for Batch: 0.53125
# Running Batch 24 from training data
# Batch no: 24,  Loss for Batch: 2.0721843242645264, Accuracy for Batch: 0.5
# Running Batch 25 from training data
# Batch no: 25,  Loss for Batch: 2.4629836082458496, Accuracy for Batch: 0.3125
# Running Batch 26 from training data
# Batch no: 26,  Loss for Batch: 2.2865965366363525, Accuracy for Batch: 0.34375
# Running Batch 27 from training data
# Batch no: 27,  Loss for Batch: 2.3434228897094727, Accuracy for Batch: 0.4375
# Running Batch 28 from training data
# Batch no: 28,  Loss for Batch: 1.9336247444152832, Accuracy for Batch: 0.421875
# Running Batch 29 from training data
# Batch no: 29,  Loss for Batch: 2.380049467086792, Accuracy for Batch: 0.375
# Running Batch 30 from training data
# Batch no: 30,  Loss for Batch: 2.0157690048217773, Accuracy for Batch: 0.46875
# Running Batch 31 from training data
# Batch no: 31,  Loss for Batch: 2.1042473316192627, Accuracy for Batch: 0.5
# Running Batch 32 from training data
# Batch no: 32,  Loss for Batch: 1.9441837072372437, Accuracy for Batch: 0.5
# Running Batch 33 from training data
# Batch no: 33,  Loss for Batch: 2.129009962081909, Accuracy for Batch: 0.390625
# Running Batch 34 from training data
# Batch no: 34,  Loss for Batch: 2.2132840156555176, Accuracy for Batch: 0.40625
# Running Batch 35 from training data
# Batch no: 35,  Loss for Batch: 2.13826060295105, Accuracy for Batch: 0.546875
# Running Batch 36 from training data
# Batch no: 36,  Loss for Batch: 1.7334685325622559, Accuracy for Batch: 0.546875
# Running Batch 37 from training data
# Batch no: 37,  Loss for Batch: 1.809712529182434, Accuracy for Batch: 0.515625
# Running Batch 38 from training data
# Batch no: 38,  Loss for Batch: 2.0285873413085938, Accuracy for Batch: 0.5
# Running Batch 39 from training data
# Batch no: 39,  Loss for Batch: 1.9855568408966064, Accuracy for Batch: 0.484375
# Running Batch 40 from training data
# Batch no: 40,  Loss for Batch: 2.1535329818725586, Accuracy for Batch: 0.515625
# Running Batch 41 from training data
# Batch no: 41,  Loss for Batch: 1.9550607204437256, Accuracy for Batch: 0.5
# Running Batch 42 from training data
# Batch no: 42,  Loss for Batch: 2.3988375663757324, Accuracy for Batch: 0.359375
# Running Batch 43 from training data
# Batch no: 43,  Loss for Batch: 2.3005619049072266, Accuracy for Batch: 0.375
# Running Batch 44 from training data
# Batch no: 44,  Loss for Batch: 1.9816192388534546, Accuracy for Batch: 0.40625
# Running Batch 45 from training data
# Batch no: 45,  Loss for Batch: 1.502432107925415, Accuracy for Batch: 0.5625
# Running Batch 46 from training data
# Batch no: 46,  Loss for Batch: 1.9629478454589844, Accuracy for Batch: 0.390625
# Running Batch 47 from training data
# Batch no: 47,  Loss for Batch: 2.18796443939209, Accuracy for Batch: 0.40625
# Running Batch 48 from training data
# Batch no: 48,  Loss for Batch: 1.9478917121887207, Accuracy for Batch: 0.453125
# Running Batch 49 from training data
# Batch no: 49,  Loss for Batch: 1.9754682779312134, Accuracy for Batch: 0.453125
# Running Batch 50 from training data
# Batch no: 50,  Loss for Batch: 2.2686893939971924, Accuracy for Batch: 0.484375
# Running Batch 51 from training data
# Batch no: 51,  Loss for Batch: 1.7860214710235596, Accuracy for Batch: 0.546875
# Running Batch 52 from training data
# Batch no: 52,  Loss for Batch: 2.3189265727996826, Accuracy for Batch: 0.359375
# Running Batch 53 from training data
# Batch no: 53,  Loss for Batch: 2.029080390930176, Accuracy for Batch: 0.46875
# Running Batch 54 from training data
# Batch no: 54,  Loss for Batch: 1.6255978345870972, Accuracy for Batch: 0.53125
# Running Batch 55 from training data
# Batch no: 55,  Loss for Batch: 1.9703197479248047, Accuracy for Batch: 0.4375
# Running Batch 56 from training data
# Batch no: 56,  Loss for Batch: 1.91898775100708, Accuracy for Batch: 0.515625
# Running Batch 57 from training data
# Batch no: 57,  Loss for Batch: 2.302272081375122, Accuracy for Batch: 0.359375
# Running Batch 58 from training data
# Batch no: 58,  Loss for Batch: 1.6931864023208618, Accuracy for Batch: 0.53125
# Running Batch 59 from training data
# Batch no: 59,  Loss for Batch: 1.981427788734436, Accuracy for Batch: 0.40625
# Running Batch 60 from training data
# Batch no: 60,  Loss for Batch: 1.8907921314239502, Accuracy for Batch: 0.46875
# Running Batch 61 from training data
# Batch no: 61,  Loss for Batch: 1.9771456718444824, Accuracy for Batch: 0.40625
# Running Batch 62 from training data
# Batch no: 62,  Loss for Batch: 2.451284646987915, Accuracy for Batch: 0.375
# Running Batch 63 from training data
# Batch no: 63,  Loss for Batch: 2.2286453247070312, Accuracy for Batch: 0.46875
# Running Batch 64 from training data
# Batch no: 64,  Loss for Batch: 2.099698543548584, Accuracy for Batch: 0.421875
# Running Batch 65 from training data
# Batch no: 65,  Loss for Batch: 2.0100481510162354, Accuracy for Batch: 0.390625
# Running Batch 66 from training data
# Batch no: 66,  Loss for Batch: 1.6271488666534424, Accuracy for Batch: 0.578125
# Running Batch 67 from training data
# Batch no: 67,  Loss for Batch: 2.0447380542755127, Accuracy for Batch: 0.5
# Running Batch 68 from training data
# Batch no: 68,  Loss for Batch: 2.1507344245910645, Accuracy for Batch: 0.46875
# Running Batch 69 from training data
# Batch no: 69,  Loss for Batch: 2.001934766769409, Accuracy for Batch: 0.46875
# Running Batch 70 from training data
# Batch no: 70,  Loss for Batch: 1.9069249629974365, Accuracy for Batch: 0.40625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 1.9075382947921753, Accuracy for Batch: 0.515625
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 1.771229863166809, Accuracy for Batch: 0.515625
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.0787453651428223, Accuracy for Batch: 0.390625
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 1.6037380695343018, Accuracy for Batch: 0.59375
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 1.6713825464248657, Accuracy for Batch: 0.5625
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 1.9741955995559692, Accuracy for Batch: 0.484375
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 1.8587429523468018, Accuracy for Batch: 0.453125
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 1.8328503370285034, Accuracy for Batch: 0.53125
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 2.2569594383239746, Accuracy for Batch: 0.40625
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 1.719321608543396, Accuracy for Batch: 0.546875
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 2.320838212966919, Accuracy for Batch: 0.5
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 2.175816297531128, Accuracy for Batch: 0.421875
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 1.9635497331619263, Accuracy for Batch: 0.40625
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 1.8234208822250366, Accuracy for Batch: 0.515625
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 1.886002779006958, Accuracy for Batch: 0.515625
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 1.6475368738174438, Accuracy for Batch: 0.515625
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 1.611452579498291, Accuracy for Batch: 0.515625
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 1.9562888145446777, Accuracy for Batch: 0.4375
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 1.870659589767456, Accuracy for Batch: 0.546875
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 2.019023895263672, Accuracy for Batch: 0.5
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 1.783453345298767, Accuracy for Batch: 0.5625
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 1.9246506690979004, Accuracy for Batch: 0.5625
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 2.3121838569641113, Accuracy for Batch: 0.5
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 1.9974772930145264, Accuracy for Batch: 0.4375
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 2.143378973007202, Accuracy for Batch: 0.421875
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 1.6407337188720703, Accuracy for Batch: 0.5
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 2.2344343662261963, Accuracy for Batch: 0.40625
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 1.9208033084869385, Accuracy for Batch: 0.5
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.415238857269287, Accuracy for Batch: 0.359375
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 2.232104539871216, Accuracy for Batch: 0.4375
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 2.1236205101013184, Accuracy for Batch: 0.46875
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 1.7783223390579224, Accuracy for Batch: 0.5
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 1.642377257347107, Accuracy for Batch: 0.4583333432674408
# Epoch: 4, Overall Training Loss: 2.0282647794890174, Overall Training Accuracy: 0.4606088101863861
# Running Epoch 5 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 1.6389652490615845, Accuracy for Batch: 0.546875
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 2.1925811767578125, Accuracy for Batch: 0.453125
# Running Batch 3 from training data
# ...
# Batch no: 70,  Loss for Batch: 1.7222918272018433, Accuracy for Batch: 0.5625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 1.9429787397384644, Accuracy for Batch: 0.53125
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 2.132721424102783, Accuracy for Batch: 0.484375
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.2122316360473633, Accuracy for Batch: 0.46875
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 1.7192356586456299, Accuracy for Batch: 0.578125
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 1.530574083328247, Accuracy for Batch: 0.515625
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 1.7486802339553833, Accuracy for Batch: 0.578125
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 2.240330457687378, Accuracy for Batch: 0.375
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 1.446075201034546, Accuracy for Batch: 0.640625
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 1.8970563411712646, Accuracy for Batch: 0.46875
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 1.5582950115203857, Accuracy for Batch: 0.59375
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 1.9744288921356201, Accuracy for Batch: 0.546875
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 1.696766972541809, Accuracy for Batch: 0.515625
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 1.7044789791107178, Accuracy for Batch: 0.53125
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 1.964900255203247, Accuracy for Batch: 0.53125
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 2.3180410861968994, Accuracy for Batch: 0.453125
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 1.9342211484909058, Accuracy for Batch: 0.484375
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 2.006171464920044, Accuracy for Batch: 0.53125
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 1.4267442226409912, Accuracy for Batch: 0.65625
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 1.8344666957855225, Accuracy for Batch: 0.546875
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 1.444941759109497, Accuracy for Batch: 0.5625
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 1.7088669538497925, Accuracy for Batch: 0.53125
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 1.6083996295928955, Accuracy for Batch: 0.5625
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 1.7243050336837769, Accuracy for Batch: 0.625
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 1.7736527919769287, Accuracy for Batch: 0.515625
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 2.130384683609009, Accuracy for Batch: 0.46875
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 1.4881541728973389, Accuracy for Batch: 0.609375
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 1.6860204935073853, Accuracy for Batch: 0.484375
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 1.7760008573532104, Accuracy for Batch: 0.515625
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.110656976699829, Accuracy for Batch: 0.453125
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 1.7098156213760376, Accuracy for Batch: 0.5625
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 2.0105466842651367, Accuracy for Batch: 0.5
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 1.914183497428894, Accuracy for Batch: 0.546875
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 2.2042417526245117, Accuracy for Batch: 0.375
# Epoch: 7, Overall Training Loss: 1.816566879309497, Overall Training Accuracy: 0.5151699185371399
# Running Epoch 8 out of 8
# Running Batch 1 from training data
# Batch no: 1,  Loss for Batch: 1.828851580619812, Accuracy for Batch: 0.4375
# Running Batch 2 from training data
# Batch no: 2,  Loss for Batch: 1.5641274452209473, Accuracy for Batch: 0.53125
# Running Batch 3 from training data
# Batch no: 3,  Loss for Batch: 1.861251711845398, Accuracy for Batch: 0.46875
# Running Batch 4 from training data
# Batch no: 4,  Loss for Batch: 1.7768006324768066, Accuracy for Batch: 0.5
# Running Batch 5 from training data
# Batch no: 5,  Loss for Batch: 1.7319945096969604, Accuracy for Batch: 0.453125
# Running Batch 6 from training data
# Batch no: 6,  Loss for Batch: 2.21500825881958, Accuracy for Batch: 0.46875
# Running Batch 7 from training data
# Batch no: 7,  Loss for Batch: 1.3524447679519653, Accuracy for Batch: 0.59375
# Running Batch 8 from training data
# Batch no: 8,  Loss for Batch: 1.6890158653259277, Accuracy for Batch: 0.5625
# Running Batch 9 from training data
# Batch no: 9,  Loss for Batch: 1.6827822923660278, Accuracy for Batch: 0.5
# Running Batch 10 from training data
# Batch no: 10,  Loss for Batch: 1.8417565822601318, Accuracy for Batch: 0.53125
# Running Batch 11 from training data
# Batch no: 11,  Loss for Batch: 1.7412692308425903, Accuracy for Batch: 0.546875
# Running Batch 12 from training data
# Batch no: 12,  Loss for Batch: 1.5540602207183838, Accuracy for Batch: 0.53125
# Running Batch 13 from training data
# Batch no: 13,  Loss for Batch: 1.4578711986541748, Accuracy for Batch: 0.625
# Running Batch 14 from training data
# Batch no: 14,  Loss for Batch: 1.6795555353164673, Accuracy for Batch: 0.546875
# Running Batch 15 from training data
# Batch no: 15,  Loss for Batch: 1.5884474515914917, Accuracy for Batch: 0.5625
# Running Batch 16 from training data
# Batch no: 16,  Loss for Batch: 1.5658799409866333, Accuracy for Batch: 0.5625
# Running Batch 17 from training data
# Batch no: 17,  Loss for Batch: 1.3722096681594849, Accuracy for Batch: 0.59375
# Running Batch 18 from training data
# Batch no: 18,  Loss for Batch: 1.8449815511703491, Accuracy for Batch: 0.53125
# Running Batch 19 from training data
# Batch no: 19,  Loss for Batch: 1.7845782041549683, Accuracy for Batch: 0.484375
# Running Batch 20 from training data
# Batch no: 20,  Loss for Batch: 1.587213397026062, Accuracy for Batch: 0.515625
# Running Batch 21 from training data
# Batch no: 21,  Loss for Batch: 1.757082223892212, Accuracy for Batch: 0.59375
# Running Batch 22 from training data
# Batch no: 22,  Loss for Batch: 1.6907198429107666, Accuracy for Batch: 0.59375
# Running Batch 23 from training data
# Batch no: 23,  Loss for Batch: 1.4648269414901733, Accuracy for Batch: 0.53125
# Running Batch 24 from training data
# Batch no: 24,  Loss for Batch: 1.7876242399215698, Accuracy for Batch: 0.53125
# Running Batch 25 from training data
# Batch no: 25,  Loss for Batch: 1.35212242603302, Accuracy for Batch: 0.671875
# Running Batch 26 from training data
# Batch no: 26,  Loss for Batch: 1.780389428138733, Accuracy for Batch: 0.5625
# Running Batch 27 from training data
# Batch no: 27,  Loss for Batch: 1.6746071577072144, Accuracy for Batch: 0.515625
# Running Batch 28 from training data
# Batch no: 28,  Loss for Batch: 1.620295524597168, Accuracy for Batch: 0.5625
# Running Batch 29 from training data
# Batch no: 29,  Loss for Batch: 2.025460958480835, Accuracy for Batch: 0.484375
# Running Batch 30 from training data
# Batch no: 30,  Loss for Batch: 1.5512797832489014, Accuracy for Batch: 0.578125
# Running Batch 31 from training data
# Batch no: 31,  Loss for Batch: 1.9749635457992554, Accuracy for Batch: 0.453125
# Running Batch 32 from training data
# Batch no: 32,  Loss for Batch: 2.178201913833618, Accuracy for Batch: 0.46875
# Running Batch 33 from training data
# Batch no: 33,  Loss for Batch: 1.9074487686157227, Accuracy for Batch: 0.53125
# Running Batch 34 from training data
# Batch no: 34,  Loss for Batch: 2.1541481018066406, Accuracy for Batch: 0.484375
# Running Batch 35 from training data
# Batch no: 35,  Loss for Batch: 1.2969796657562256, Accuracy for Batch: 0.625
# Running Batch 36 from training data
# Batch no: 36,  Loss for Batch: 1.908557415008545, Accuracy for Batch: 0.484375
# Running Batch 37 from training data
# Batch no: 37,  Loss for Batch: 1.645982027053833, Accuracy for Batch: 0.484375
# Running Batch 38 from training data
# Batch no: 38,  Loss for Batch: 1.590274691581726, Accuracy for Batch: 0.546875
# Running Batch 39 from training data
# Batch no: 39,  Loss for Batch: 1.567288875579834, Accuracy for Batch: 0.5625
# Running Batch 40 from training data
# Batch no: 40,  Loss for Batch: 1.3674829006195068, Accuracy for Batch: 0.625
# Running Batch 41 from training data
# Batch no: 41,  Loss for Batch: 1.720902681350708, Accuracy for Batch: 0.546875
# Running Batch 42 from training data
# Batch no: 42,  Loss for Batch: 1.8228596448898315, Accuracy for Batch: 0.484375
# Running Batch 43 from training data
# Batch no: 43,  Loss for Batch: 1.6553019285202026, Accuracy for Batch: 0.53125
# Running Batch 44 from training data
# Batch no: 44,  Loss for Batch: 1.8531378507614136, Accuracy for Batch: 0.40625
# Running Batch 45 from training data
# Batch no: 45,  Loss for Batch: 2.2017946243286133, Accuracy for Batch: 0.40625
# Running Batch 46 from training data
# Batch no: 46,  Loss for Batch: 1.6113197803497314, Accuracy for Batch: 0.546875
# Running Batch 47 from training data
# Batch no: 47,  Loss for Batch: 1.7731271982192993, Accuracy for Batch: 0.53125
# Running Batch 48 from training data
# Batch no: 48,  Loss for Batch: 1.9283643960952759, Accuracy for Batch: 0.5
# Running Batch 49 from training data
# Batch no: 49,  Loss for Batch: 1.6535935401916504, Accuracy for Batch: 0.46875
# Running Batch 50 from training data
# Batch no: 50,  Loss for Batch: 1.6560381650924683, Accuracy for Batch: 0.59375
# Running Batch 51 from training data
# Batch no: 51,  Loss for Batch: 1.9058431386947632, Accuracy for Batch: 0.4375
# Running Batch 52 from training data
# Batch no: 52,  Loss for Batch: 1.563625693321228, Accuracy for Batch: 0.578125
# Running Batch 53 from training data
# Batch no: 53,  Loss for Batch: 1.3735935688018799, Accuracy for Batch: 0.640625
# Running Batch 54 from training data
# Batch no: 54,  Loss for Batch: 1.8473888635635376, Accuracy for Batch: 0.46875
# Running Batch 55 from training data
# Batch no: 55,  Loss for Batch: 2.3111486434936523, Accuracy for Batch: 0.4375
# Running Batch 56 from training data
# Batch no: 56,  Loss for Batch: 1.3746362924575806, Accuracy for Batch: 0.578125
# Running Batch 57 from training data
# Batch no: 57,  Loss for Batch: 2.034926414489746, Accuracy for Batch: 0.5625
# Running Batch 58 from training data
# Batch no: 58,  Loss for Batch: 2.1101105213165283, Accuracy for Batch: 0.421875
# Running Batch 59 from training data
# Batch no: 59,  Loss for Batch: 2.279848575592041, Accuracy for Batch: 0.5
# Running Batch 60 from training data
# Batch no: 60,  Loss for Batch: 1.7026219367980957, Accuracy for Batch: 0.5625
# Running Batch 61 from training data
# Batch no: 61,  Loss for Batch: 1.3575738668441772, Accuracy for Batch: 0.625
# Running Batch 62 from training data
# Batch no: 62,  Loss for Batch: 1.8585751056671143, Accuracy for Batch: 0.4375
# Running Batch 63 from training data
# Batch no: 63,  Loss for Batch: 1.8258601427078247, Accuracy for Batch: 0.578125
# Running Batch 64 from training data
# Batch no: 64,  Loss for Batch: 2.108123540878296, Accuracy for Batch: 0.40625
# Running Batch 65 from training data
# Batch no: 65,  Loss for Batch: 1.5228525400161743, Accuracy for Batch: 0.5625
# Running Batch 66 from training data
# Batch no: 66,  Loss for Batch: 1.7306541204452515, Accuracy for Batch: 0.59375
# Running Batch 67 from training data
# Batch no: 67,  Loss for Batch: 1.916821002960205, Accuracy for Batch: 0.46875
# Running Batch 68 from training data
# Batch no: 68,  Loss for Batch: 1.8300539255142212, Accuracy for Batch: 0.46875
# Running Batch 69 from training data
# Batch no: 69,  Loss for Batch: 1.69600248336792, Accuracy for Batch: 0.5
# Running Batch 70 from training data
# Batch no: 70,  Loss for Batch: 1.9742848873138428, Accuracy for Batch: 0.390625
# Running Batch 71 from training data
# Batch no: 71,  Loss for Batch: 1.3770869970321655, Accuracy for Batch: 0.6875
# Running Batch 72 from training data
# Batch no: 72,  Loss for Batch: 1.8518333435058594, Accuracy for Batch: 0.515625
# Running Batch 73 from training data
# Batch no: 73,  Loss for Batch: 2.1324243545532227, Accuracy for Batch: 0.34375
# Running Batch 74 from training data
# Batch no: 74,  Loss for Batch: 1.7751802206039429, Accuracy for Batch: 0.546875
# Running Batch 75 from training data
# Batch no: 75,  Loss for Batch: 1.7951661348342896, Accuracy for Batch: 0.46875
# Running Batch 76 from training data
# Batch no: 76,  Loss for Batch: 1.886650800704956, Accuracy for Batch: 0.546875
# Running Batch 77 from training data
# Batch no: 77,  Loss for Batch: 1.9358031749725342, Accuracy for Batch: 0.421875
# Running Batch 78 from training data
# Batch no: 78,  Loss for Batch: 1.7250347137451172, Accuracy for Batch: 0.546875
# Running Batch 79 from training data
# Batch no: 79,  Loss for Batch: 1.7562669515609741, Accuracy for Batch: 0.53125
# Running Batch 80 from training data
# Batch no: 80,  Loss for Batch: 1.5181467533111572, Accuracy for Batch: 0.59375
# Running Batch 81 from training data
# Batch no: 81,  Loss for Batch: 1.782599925994873, Accuracy for Batch: 0.515625
# Running Batch 82 from training data
# Batch no: 82,  Loss for Batch: 1.6562633514404297, Accuracy for Batch: 0.640625
# Running Batch 83 from training data
# Batch no: 83,  Loss for Batch: 1.829939842224121, Accuracy for Batch: 0.453125
# Running Batch 84 from training data
# Batch no: 84,  Loss for Batch: 1.8924485445022583, Accuracy for Batch: 0.453125
# Running Batch 85 from training data
# Batch no: 85,  Loss for Batch: 1.5955339670181274, Accuracy for Batch: 0.578125
# Running Batch 86 from training data
# Batch no: 86,  Loss for Batch: 1.890741229057312, Accuracy for Batch: 0.484375
# Running Batch 87 from training data
# Batch no: 87,  Loss for Batch: 2.2250969409942627, Accuracy for Batch: 0.390625
# Running Batch 88 from training data
# Batch no: 88,  Loss for Batch: 1.8622058629989624, Accuracy for Batch: 0.515625
# Running Batch 89 from training data
# Batch no: 89,  Loss for Batch: 1.7376201152801514, Accuracy for Batch: 0.5625
# Running Batch 90 from training data
# Batch no: 90,  Loss for Batch: 1.807620644569397, Accuracy for Batch: 0.46875
# Running Batch 91 from training data
# Batch no: 91,  Loss for Batch: 1.737349510192871, Accuracy for Batch: 0.546875
# Running Batch 92 from training data
# Batch no: 92,  Loss for Batch: 1.4559335708618164, Accuracy for Batch: 0.59375
# Running Batch 93 from training data
# Batch no: 93,  Loss for Batch: 1.9308990240097046, Accuracy for Batch: 0.53125
# Running Batch 94 from training data
# Batch no: 94,  Loss for Batch: 2.222735643386841, Accuracy for Batch: 0.46875
# Running Batch 95 from training data
# Batch no: 95,  Loss for Batch: 1.7713359594345093, Accuracy for Batch: 0.46875
# Running Batch 96 from training data
# Batch no: 96,  Loss for Batch: 1.6816761493682861, Accuracy for Batch: 0.5625
# Running Batch 97 from training data
# Batch no: 97,  Loss for Batch: 1.9510859251022339, Accuracy for Batch: 0.53125
# Running Batch 98 from training data
# Batch no: 98,  Loss for Batch: 1.9888666868209839, Accuracy for Batch: 0.4375
# Running Batch 99 from training data
# Batch no: 99,  Loss for Batch: 2.283543825149536, Accuracy for Batch: 0.453125
# Running Batch 100 from training data
# Batch no: 100,  Loss for Batch: 2.141674280166626, Accuracy for Batch: 0.421875
# Running Batch 101 from training data
# Batch no: 101,  Loss for Batch: 1.7337881326675415, Accuracy for Batch: 0.5625
# Running Batch 102 from training data
# Batch no: 102,  Loss for Batch: 1.4764989614486694, Accuracy for Batch: 0.5
# Running Batch 103 from training data
# Batch no: 103,  Loss for Batch: 1.1911568641662598, Accuracy for Batch: 0.7916666865348816
# Epoch: 8, Overall Training Loss: 1.7652138830388633, Overall Training Accuracy: 0.5224009156227112
# Training finished at: 1688851292.1717188
# Total time to run through 8 epochs: 910.5308797359467

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
cuda = torch.cuda.is_available()
with torch.no_grad():
    model.eval() # setting model to evaluation mode
    # validation loop
    overall_accuracy = 0.0
    for valid_loop_i, (images, labels) in enumerate(valid_loader):
        if cuda:
            images = images.to('cuda')
            labels = labels.to('cuda')
        # foward
        outputs = model(images)
        loss = criterion(outputs, labels)

        probabilites = torch.exp(outputs).data
        _, top_class = torch.max(outputs.data, 1)
        equality = (labels == top_class)
        accuracy = torch.mean(equality.type(torch.FloatTensor)).item()
        overall_accuracy += accuracy
        print("Validation Loop: {} Accuracy: {}".format(valid_loop_i, accuracy))
    print('Overall Accuracy: {}'.format(overall_accuracy/len(valid_loader)))
# Out:
# Validation Loop: 0 Accuracy: 0.765625
# Validation Loop: 1 Accuracy: 0.796875
# Validation Loop: 2 Accuracy: 0.859375
# Validation Loop: 3 Accuracy: 0.71875
# Validation Loop: 4 Accuracy: 0.890625
# Validation Loop: 5 Accuracy: 0.71875
# Validation Loop: 6 Accuracy: 0.96875
# Validation Loop: 7 Accuracy: 0.890625
# Validation Loop: 8 Accuracy: 0.921875
# Validation Loop: 9 Accuracy: 1.0
# Validation Loop: 10 Accuracy: 0.609375
# Validation Loop: 11 Accuracy: 0.796875
# Validation Loop: 12 Accuracy: 0.699999988079071
# Overall Accuracy: 0.8182692298522363

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint
model.class_to_idx = training_datasets.class_to_idx
torch.save({'input_size': 25088,
            'hidden layer': 1024,
             'output_size': 102,
            'dropout': 0.5,
             'epochs': 10,
             'model architecture': 'vgg19',
            'optimizer': optimizer.state_dict(),
            'classifier': model.classifier,
             'learning_rate': 0.001,
             'model_state_dict': model.state_dict(),
             'model_class_to_idx': model.class_to_idx}, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
# gets checkpoint from file created in code cell above
checkpoint_path = 'checkpoint.pth'

def load_checkpoint(filename):
    checkpoint = torch.load(filename)
    model = getattr(torchvision.models, checkpoint['model architecture'])(pretrained = True)
    model.classifier = checkpoint['classifier']
    model.epochs = checkpoint['epochs']
    model.model_state_dict = checkpoint['model_state_dict']
    model.optimizer = checkpoint['optimizer']
    model.class_to_idx = checkpoint['model_class_to_idx']
    return model, optimizer

model, optimizer = load_checkpoint(checkpoint_path)
print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): Linear(in_features=1024, out_features=102, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    image = Image.open(image)
    transformations = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     normalization])
    image_tensor = transformations(image)
    return image_tensor

    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    cuda = torch.cuda.is_available()
    model.cpu()
    image = process_image(image_path)

    model.eval() # setting model to evaluation mode
    image_tensor = torch.from_numpy(numpy.expand_dims(process_image(image_path),
                                                  axis=0)).type(torch.FloatTensor).float()
    output = model.forward(image_tensor)
    probabilities = torch.exp(output).data
    # getting top five probabilities and indexes
    top_probs, top_labels = probabilities.topk(topk)
    top_probs = numpy.array(top_probs.detach())[0]
    top_labels = numpy.array(top_labels.detach())[0]
    return_classes = []
    for label in top_labels:
        return_classes.append(label)
    return top_probs, return_classes



    # TODO: Implement the code to predict the class from an image file

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
img = random.choice(os.listdir('/content/drive/MyDrive/Colab Notebooks/flowers/test/7/'))
img_path = '/content/drive/MyDrive/Colab Notebooks/flowers/test/7/' + img
image = Image.open(img_path)
probabilities, classes = predict(img_path, model)
flower_classes = [cat_to_name[str(i)] for i in classes]
most_likely_flower = probabilities[numpy.argmax(probabilities)]
most_likely_flower_label = classes[numpy.argmax(probabilities)]
fig = plt.figure(figsize=(6,10))
ax1 = plt.subplot(2,1,1)
ax1.imshow(image)
ax1.set_axis_off()
ax1.set_title(cat_to_name[str(most_likely_flower_label)])
ax2 = plt.subplot(2,1,2)
y_ticks = numpy.arange(5)
ax2.set_yticks(y_ticks)
ax2.set_yticklabels(flower_classes)
ax2.set_xlabel('Probability')
plt.barh(y_ticks, probabilities)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
